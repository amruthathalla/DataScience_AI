# %%
import matplotlib

# %%
import numpy as np

# %%
from PIL import Image

# %%
Image = Image.open(r'C:\Users\Amrutha Thalla\Desktop\image.jpg')
Image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x691>

# %%
type(Image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
ele_arr = np.asarray(Image)
ele_arr
# Out:
# array([[[203, 213, 225],
#         [203, 213, 225],
#         [203, 213, 225],
#         ...,
#         [210, 222, 238],
#         [212, 224, 240],
#         [212, 224, 240]],
#
#        [[203, 213, 225],
#         [203, 213, 225],
#         [203, 213, 225],
#         ...,
#         [210, 222, 238],
#         [211, 223, 239],
#         [212, 224, 240]],
#
#        [[203, 213, 225],
#         [203, 213, 225],
#         [203, 213, 225],
#         ...,
#         [209, 221, 237],
#         [211, 223, 239],
#         [212, 224, 240]],
#
#        ...,
#
#        [[188, 188, 152],
#         [194, 194, 158],
#         [191, 192, 158],
#         ...,
#         [225, 224, 176],
#         [209, 207, 158],
#         [219, 213, 165]],
#
#        [[189, 189, 153],
#         [196, 196, 160],
#         [193, 194, 160],
#         ...,
#         [225, 224, 176],
#         [210, 208, 159],
#         [221, 215, 167]],
#
#        [[189, 189, 153],
#         [197, 197, 161],
#         [196, 197, 163],
#         ...,
#         [226, 225, 177],
#         [211, 209, 160],
#         [224, 218, 170]]], shape=(691, 1024, 3), dtype=uint8)

# %%
ele_arr.shape
# Out:
# (691, 1024, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(ele_arr)

# %%
ele_arr.shape
# Out:
# (691, 1024, 3)

# %%
plt.gca()
# Out:
# <Axes: >

# %%
plt.gcf()

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
# Plotting from a Jupyter notebook

# %%
# %matplotlib inline
x1=np.linspace(0,10,50)
plt.plot(x1, np.sin(x1), '-')
plt.plot(x1, np.cos(x1), '*')
plt.show()

# %%
plt.gcf() #get current figure

# %%
plt.gca() #get current axes
# Out:
# <Axes: >

# %%
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1), '*')

# %%
# create a plot figure
plt.figure()


# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))

# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));

# %%
print(plt.gcf())
plt.show()
# Out:
# Figure(640x480)

# %%
#visualization with pyplot

# %%
plt.plot([1,2,3,4], [1,8,2,16])
plt.ylabel('Numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 8, 27, 64])
plt.show()
