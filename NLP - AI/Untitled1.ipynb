# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in c:\anaconda3\lib\site-packages (5.5.0)
# Requirement already satisfied: torch in c:\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\anaconda3\lib\site-packages (from transformers) (1.9.2)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda3\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda3\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\anaconda3\lib\site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\anaconda3\lib\site-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: click>=8.2.1 in c:\anaconda3\lib\site-packages (from typer->transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\anaconda3\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\anaconda3\lib\site-packages (from typer->transformers) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\anaconda3\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda3\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda3\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.9.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda3\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda3\lib\site-packages (from transformers) (6.0.3)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in c:\anaconda3\lib\site-packages (from transformers) (0.24.0)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in c:\anaconda3\lib\site-packages (from typer->transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\anaconda3\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\anaconda3\lib\site-packages (from typer->transformers) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\anaconda3\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda3\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda3\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    --------------------- ------------------ 5.5/10.2 MB 27.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 27.4 MB/s  0:00:00
# Downloading huggingface_hub-1.9.2-py3-none-any.whl (637 kB)
#    ---------------------------------------- 0.0/637.3 kB ? eta -:--:--
#    ---------------------------------------- 637.3/637.3 kB 15.1 MB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ---------------------------------------- 3.7/3.7 MB 31.2 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 32.6 MB/s  0:00:00
# Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl (277 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Installing collected packages: safetensors, regex, hf-xet, huggingface-hub, tokenizers, transformers
#
#   Attempting uninstall: regex
#
#     Found existing installation: regex 2025.9.1
#
#    ------ --------------------------------- 1/6 [regex]
#     Uninstalling regex-2025.9.1:
#    ------ --------------------------------- 1/6 [regex]
#       Successfully uninstalled regex-2025.9.1
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#   Attempting uninstall: hf-xet
#    ------ --------------------------------- 1/6 [regex]
#     Found existing installation: hf-xet 1.2.0
#    ------ --------------------------------- 1/6 [regex]
#     Uninstalling hf-xet-1.2.0:
#    ------ --------------------------------- 1/6 [regex]
#       Successfully uninstalled hf-xet-1.2.0
#    ------ --------------------------------- 1/6 [regex]
#   Attempting uninstall: huggingface-hub
#    ------ --------------------------------- 1/6 [regex]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#     Found existing installation: huggingface_hub 1.4.1
#    -------------------- ------------------- 3/6 [huggingface-hub]
#     Uninstalling huggingface_hub-1.4.1:
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#       Successfully uninstalled huggingface_hub-1.4.1
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [tokenizers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    ---------------------------------------- 6/6 [transformers]
#
# Successfully installed hf-xet-1.4.3 huggingface-hub-1.9.2 regex-2026.4.4 safetensors-0.7.0 tokenizers-0.22.2 transformers-5.5.0

# %%
# !pip install nvidia-smi
# Out:
# Collecting nvidia-smi
#   Downloading nvidia_smi-0.1.3-py36-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.16.2 in c:\anaconda3\lib\site-packages (from nvidia-smi) (2.3.5)
# Requirement already satisfied: six>=1.12.0 in c:\anaconda3\lib\site-packages (from nvidia-smi) (1.17.0)
# Collecting sorcery>=0.1.0 (from nvidia-smi)
#   Downloading sorcery-0.2.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pytest>=4.3.1 in c:\anaconda3\lib\site-packages (from nvidia-smi) (8.4.2)
# Requirement already satisfied: colorama>=0.4 in c:\anaconda3\lib\site-packages (from pytest>=4.3.1->nvidia-smi) (0.4.6)
# Requirement already satisfied: iniconfig>=1 in c:\anaconda3\lib\site-packages (from pytest>=4.3.1->nvidia-smi) (2.1.0)
# Requirement already satisfied: packaging>=20 in c:\anaconda3\lib\site-packages (from pytest>=4.3.1->nvidia-smi) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\anaconda3\lib\site-packages (from pytest>=4.3.1->nvidia-smi) (1.5.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\anaconda3\lib\site-packages (from pytest>=4.3.1->nvidia-smi) (2.19.2)
# Requirement already satisfied: executing in c:\anaconda3\lib\site-packages (from sorcery>=0.1.0->nvidia-smi) (2.2.1)
# Collecting littleutils>=0.2.1 (from sorcery>=0.1.0->nvidia-smi)
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: asttokens in c:\anaconda3\lib\site-packages (from sorcery>=0.1.0->nvidia-smi) (3.0.0)
# Requirement already satisfied: wrapt in c:\anaconda3\lib\site-packages (from sorcery>=0.1.0->nvidia-smi) (1.17.0)
# Downloading nvidia_smi-0.1.3-py36-none-any.whl (11 kB)
# Downloading sorcery-0.2.2-py3-none-any.whl (16 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: littleutils, sorcery, nvidia-smi
#
#    -------------------------- ------------- 2/3 [nvidia-smi]
#    ---------------------------------------- 3/3 [nvidia-smi]
#
# Successfully installed littleutils-0.2.4 nvidia-smi-0.1.3 sorcery-0.2.2

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("gpt2")

text = "Hello, how are you?"

tokens= tokenizer(text, return_tensors='pt')
print(tokens)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# {'input_ids': tensor([[15496,    11,   703,   389,   345,    30]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load tokenizer + model (GPT-2)
model = AutoModelForCausalLM.from_pretrained("gpt2")

# Generate text
input_ids = tokenizer.encode("india economy", return_tensors='pt')

output = model.generate(
    input_ids,
    max_length=100,
)

generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(generated_text)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# india economy.
#
# The government has also announced that it will introduce a new law to allow women to vote in the upcoming elections.
#
# The government has also announced that it will introduce a new law to allow women to vote in the upcoming elections.
#
# The government has also announced that it will introduce a new law to allow women to vote in the upcoming elections.
#
# The government has also announced that it will introduce a new law to allow women to vote in the upcoming elections.

# %%
# HUGGING FACE SECTION

from transformers import pipeline, set_seed

generator = pipeline('text-generation', model='gpt2')

set_seed(42)

generator(
    "About IPL cricket matches in India and IPL revenue,",
    max_length=30,
    num_return_sequences=5
)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'About IPL cricket matches in India and IPL revenue, we expect to grow at around Rs 9.5 crore by 2020. This means the company\'s revenue will reach Rs 8.5 crore per match in the next three years."\n\nThe company also mentioned that it is working with the Indian cricket boards to set up a team to play IPL matches in the country.\n\n"We have also given the boards permission to send teams to India when we are ready. We will also send teams to India when we need them and we will also organise a team," the company said.\n\nThe team will be led by Virat Kohli who is ranked No. 12 in the world at the moment and is currently being promoted to No. 20.\n\nOn the other hand, the company also expressed interest in joining up with the Indian Cyber Sports Commission (ICSC), a body that has been established by the Indian government to promote cyber sports.'},
#  {'generated_text': 'About IPL cricket matches in India and IPL revenue, which have been steadily declining for years.\n\nIndian cricket teams played 434 matches last year in their first year under IPL, which has been declining for years.\n\nThe decline in the number of international franchises has been largely attributed to India being the poorest country in the world.\n\nIndia is the fifth poorest country in the world after Pakistan and Sri Lanka.\n\nIt has also been the third poorest country in the world after Nigeria and Sudan.\n\nHindustan Times/File Photo\n\nIn a report published on Monday, IPS director general Dilip Sharma said the latest figures show IPL revenue growth in India was down to a mere Rs 2.5 lakh per match every 15 days, compared with Rs 1.2 lakh per match a year earlier.\n\n"The decline in the number of franchises is largely attributed to the declining number of international franchises. The number of leagues is declining and the number of domestic franchises has declined. This decline is partly due to the decline of the domestic franchise, which has been declining for years.\n\n"The decline in IPL revenue has been largely attributed to the decline of the domestic franchise. As a result, the number of leagues has decreased. The number of domestic franchises has decreased," he said.'},
#  {'generated_text': 'About IPL cricket matches in India and IPL revenue, the revenue is expected to rise by 50 per cent this year. In the last couple of years, revenue from these matches has risen by about 20 per cent while revenue from IPL matches fell by 15 per cent.\n\n"It is a matter of how much revenue we can generate by generating better match results. This is another way to get the revenue that we need to make the game better," says Gopal.\n\nBut Gopal also sees a need for a more aggressive approach in the sports industry. "We want to get the most out of the game," says Gopal.\n\nIn India, the last four years, the league has generated revenue of Rs.17.1 billion. In the last three years, the league has generated Rs.24.9 billion. In 2013, the league generated Rs.19.7 billion. It is forecast to generate Rs.44.2 billion in revenue in 2014 and Rs.25.8 billion in 2015.\n\nGopal has also raised the hope that the Indian football industry is ready to embrace the sport. "As a spectator sport in India, we have to invest in that. We have to invest in the technology and so we have to invest in the infrastructure and so we have to invest in'},
#  {'generated_text': "About IPL cricket matches in India and IPL revenue, a more detailed analysis of the financial results of the IPL and the league in India is to be published in the upcoming edition of the magazine, 'India Cricket'.\n\nThe IPL is an international competition involving nearly 20,000 players from more than 50 countries. Its success in India has been a huge surprise to many. The global cricket market has grown in recent years and the IPL is one of the most popular international leagues in the world.\n\nIn the next few months, the Indian players will have the opportunity to play in one of the five major IPL matches, from December to March. The IPL is a competition between the best and worst sides of the world. The top two teams will face off for the top spot in the world rankings. The IPL's top four teams will play in a special event held in New Delhi on March 25, with the three remaining teams of the top four to play host to the semi-final against the top two teams of the world. Following the tournament, the top three teams will play in an exclusive event at the top of the world rankings.\n\nThe tournament has been hosted in Mumbai, Mumbai-on-Thames, Lucknow, Chennai-Kolkata and Bengaluru. It will have"},
#  {'generated_text': 'About IPL cricket matches in India and IPL revenue, the tournament will also be watched closely by the public.\n\nThe IPL has a global footprint and will be watched closely by fans across the world and in the region. The tournament will be watched closely by broadcasters from all over the world and will be watched live on Twitch, Youtube, Twitter and in the Indian space, as well as by local media.\n\nThe IPL will feature 12 live IPL matches against each other and will be made available on the Indian website and in the Indian space.\n\n"We are deeply excited to welcome IPL Cricket India to the Indian space and we look forward to seeing everything done at the IPL," said Rajesh Kumar, Managing Director, India Cricket Board. "We are keen to gain more momentum in the IPL as IPL has a long way to go."\n\nKumar further confirmed that IPL is currently undergoing Phase III of the project. The first phase of the project will focus on expanding the tournament to over 400 cities and towns, including around 6,500 in Karnataka and around 2,500 in Tamil Nadu.\n\n"We are looking forward to seeing how the IPL evolves in the future. We have already got a couple of cities that are ready and we will see how the IP'}]
