# %%
#Open cv and image processing

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    - -------------------------------------- 1.8/40.2 MB 16.6 MB/s eta 0:00:03
#    -------- ------------------------------- 8.9/40.2 MB 30.0 MB/s eta 0:00:02
#    -------------- ------------------------- 14.2/40.2 MB 27.4 MB/s eta 0:00:01
#    --------------------- ------------------ 22.0/40.2 MB 30.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 29.4/40.2 MB 31.1 MB/s eta 0:00:01
#    ------------------------------------- -- 37.5/40.2 MB 32.4 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 28.9 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\Amrutha Thalla\Desktop\image.jpg')

# %%
img
# Out:
# array([[[225, 213, 203],
#         [225, 213, 203],
#         [225, 213, 203],
#         ...,
#         [238, 222, 210],
#         [240, 224, 212],
#         [240, 224, 212]],
#
#        [[225, 213, 203],
#         [225, 213, 203],
#         [225, 213, 203],
#         ...,
#         [238, 222, 210],
#         [239, 223, 211],
#         [240, 224, 212]],
#
#        [[225, 213, 203],
#         [225, 213, 203],
#         [225, 213, 203],
#         ...,
#         [237, 221, 209],
#         [239, 223, 211],
#         [240, 224, 212]],
#
#        ...,
#
#        [[152, 187, 190],
#         [160, 194, 194],
#         [158, 192, 192],
#         ...,
#         [178, 225, 223],
#         [161, 207, 208],
#         [166, 214, 216]],
#
#        [[153, 189, 189],
#         [160, 196, 196],
#         [162, 194, 193],
#         ...,
#         [176, 224, 225],
#         [160, 208, 210],
#         [167, 215, 219]],
#
#        [[153, 189, 189],
#         [161, 197, 197],
#         [165, 197, 196],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
#matplotlib     --> r g b 
#opencv channel --> b g r

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\Amrutha Thalla\Desktop\image.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
plt.imshow(img_gray, cmap = 'Accent')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (691, 1024, 3)

# %%
fix_img_1=cv2.resize(fix_img,(500,367))

# %%
plt.imshow(fix_img_1)

# %%
img3=cv2.flip(fix_img_1,0)

# %%
plt.imshow(img3)

# %%
img3=cv2.flip(fix_img_1,1)
plt.imshow(img3)

# %%
img3=cv2.flip(fix_img_1,3)
plt.imshow(img3)
